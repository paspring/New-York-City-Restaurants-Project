# %%
import pandas as pd 
foursquare=pd.read_csv('dataset/restaurants_only.csv',index_col=0)
print(foursquare.shape)
foursquare.head()
# Out:
# (3402, 30)
#                                  name          categories         address  \
# 0                      403 Restaurant  Chinese Restaurant  403 Church Ave
# 3       Mi Barrio Taqueria Restaurant  Mexican Restaurant   3415 14th Ave
# 4        Ghoroa Sweets and Restaurant          Restaurant             NaN
# 9   New Fulin Kwok Seafood Restaurant  Seafood Restaurant    4619 8th Ave
# 11            King Chinese Restaurant  Chinese Restaurant    4503 8th Ave
#
#     crossStreet        lat        lng  \
# 0   East 4th St  40.639459 -73.979728
# 3           NaN  40.641598 -73.981458
# 4           NaN  40.642388 -73.979681
# 9           NaN  40.642820 -74.001534
# 11          NaN  40.643611 -74.000919
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 40.63945917816107...       103      11218
# 3   [{'label': 'display', 'lat': 40.64159799999999...       228      11218
# ...

# %%
c=foursquare.Neighborhood.value_counts()
b=foursquare.Borough.value_counts()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.bar(c.index[0:10],c[0:10])
ax.set_xticklabels(c.index, rotation=90)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5,5))
ax.bar(b.index,b)
ax.set_xticklabels(b.index, rotation=90)
plt.show()

# %%
d=foursquare.groupby("Borough")['Price'].mean()
d
# Out:
# Borough
# Bronx            1.708075
# Brooklyn         1.753086
# Manhattan        2.236948
# Queens           1.629758
# Staten Island    2.200000
# Name: Price, dtype: float64

# %%
e=foursquare.groupby("Borough")['Rating'].mean()
e
# Out:
# Borough
# Bronx            7.281250
# Brooklyn         7.043673
# Manhattan        7.178664
# Queens           7.144105
# Staten Island    7.330000
# Name: Rating, dtype: float64

# %%
foursquare.sort_values(by="Rating", ascending=False)
# Out:
#                                     name                 categories  \
# 6926          Archestratus Books & Foods                 Restaurant
# 297                   Evelina Restaurant         Italian Restaurant
# 3721                               Marea         Seafood Restaurant
# 670           Arepera Guacuco Restaurant  Latin American Restaurant
# 1682               Frankies 457 Spuntino         Italian Restaurant
# ...                                  ...                        ...
# 8657               Catria Modern Italian         Italian Restaurant
# 8662  Nic & Dora's Italian Sandwich Shop         Italian Restaurant
# 8664                  Italian Rifle Club         Italian Restaurant
# 8666         New York Italian Kitchen #2         Italian Restaurant
# 8667             La Vela Cucina Italiana         Italian Restaurant
#
#                  address              crossStreet        lat        lng  \
# 6926        160 Huron St                      NaN  40.732905 -73.955365
# ...
